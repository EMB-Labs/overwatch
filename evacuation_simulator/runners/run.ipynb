# %%
from run_agent_path_demo import run_demo_full
# 1) 시나리오1: 비교대조군 (baseline과 동일, 리라우트만 켜진 버전): dyn_s1_baseline
# 2) 시나리오2: 310 화재 (F3_ROOM_310): dyn_s2_310_fire
# 3) 시나리오3: 206 화재 (F2_ROOM_206): dyn_s3_206_fire
# 4) 시나리오4: 114 화재 (F1_ROOM_114): dyn_s4_114_fire
# 5) 시나리오5: 103 화재 (F1_ROOM_103): dyn_s5_103_fire
# 6) 시나리오6: 114 화재 + 20s 후 113,115 화재: dyn_s6_114_then_113_115
# 7) 시나리오7: 306 화재 + 20s 후 3F_HALL_13,14,15 block: dyn_s7_206_fire_then_3F_hall_block
# 8) 시나리오8: 310 화재: dyn_s8_310_fire
# 9) 시나리오9: 210 화재 + 10s 후 2F_STAIR2 block: dyn_s9_210_fire_then_stair2_block
# 10) 시나리오10: 307 화재 + 20s 후 2F_EXIT_B block: dyn_s10_307_fire_then_exitB_block
# 11) 시나리오11: 혼잡도 급증 – 계단1 throughput 급락 → 리라우트 유도: dyn_s11_congestion_spike_stair1
# 12) 시나리오12: 혼잡도 급증 – EXIT_B throughput 급락 → 리라우트 유도: dyn_s12_congestion_spike_exitB

res = run_demo_full("dyn_s10_307_fire_then_exitB_block", 800)
# Out:
# ...
# [Scenario] dyn_s10_307_fire_then_exitB_block
# [Agent] index=800, id=200
# - initial_path (node list):
#    ['F3_ROOM_309', 'F3_DOOR_309_B', 'F3_HALL_10', 'F3_HALL_11', 'F3_HALL_12', 'F3_HALL_13', 'F3_HALL_14', 'F3_HALL_15', 'F3_STAIR_2', 'F2_STAIR_2', 'F2_HALL_15', 'F2_EXIT_B', 'SUPER_EXIT']
# - final_path (node list):
#    ['F2_STAIR_2', 'F1_STAIR_2', 'F1_HALL_13', 'F1_HALL_12', 'F1_HALL_20', 'F1_HALL_14', 'F1_HALL_15', 'F1_HALL_16', 'F1_HALL_17', 'F1_HALL_18', 'F1_HALL_19', 'F1_EXIT_C', 'SUPER_EXIT']
# - path timeline (time → path):
#   t=0.0s : ['F3_ROOM_309', 'F3_DOOR_309_B', 'F3_HALL_10', 'F3_HALL_11', 'F3_HALL_12', 'F3_HALL_13', 'F3_HALL_14', 'F3_HALL_15', 'F3_STAIR_2', 'F2_STAIR_2', 'F2_HALL_15', 'F2_EXIT_B', 'SUPER_EXIT']
#   t=21.0s : ['F3_HALL_12', 'F3_HALL_13', 'F3_HALL_14', 'F3_HALL_15', 'F3_STAIR_2', 'F2_STAIR_2', 'F1_STAIR_2', 'F1_HALL_13', 'F1_EXIT_B', 'SUPER_EXIT']
# ...
