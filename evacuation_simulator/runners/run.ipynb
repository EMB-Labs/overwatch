# %%
from run_agent_path_demo import run_demo_full
# 1) 시나리오1: 비교대조군 (baseline과 동일, 리라우트만 켜진 버전): dyn_s1_baseline
# 2) 시나리오2: 310 화재 (F3_ROOM_310): dyn_s2_310_fire
# 3) 시나리오3: 206 화재 (F2_ROOM_206): dyn_s3_206_fire
# 4) 시나리오4: 114 화재 (F1_ROOM_114): dyn_s4_114_fire
# 5) 시나리오5: 103 화재 (F1_ROOM_103): dyn_s5_103_fire
# 6) 시나리오6: 114 화재 + 20s 후 113,115 화재: dyn_s6_114_then_113_115
# 7) 시나리오7: 306 화재 + 20s 후 3F_HALL_13,14,15 block: dyn_s7_206_fire_then_3F_hall_block
# 8) 시나리오8: 310 화재: dyn_s8_310_fire
# 9) 시나리오9: 210 화재 + 10s 후 2F_STAIR2 block: dyn_s9_210_fire_then_stair2_block
# 10) 시나리오10: 307 화재 + 20s 후 2F_EXIT_B block: dyn_s10_307_fire_then_exitB_block
# 11) 시나리오11: 혼잡도 급증 – 계단1 throughput 급락 → 리라우트 유도: dyn_s11_congestion_spike_stair1
# 12) 시나리오12: 혼잡도 급증 – EXIT_B throughput 급락 → 리라우트 유도: dyn_s12_congestion_spike_exitB

res = run_demo_full("dyn_s12_congestion_spike_exitB", 1200)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from run_agent_path_demo import run_demo_full
#       2 # 1) 시나리오1: 비교대조군 (baseline과 동일, 리라우트만 켜진 버전): dyn_s1_baseline
#       3 # 2) 시나리오2: 310 화재 (F3_ROOM_310): dyn_s2_310_fire
#       4 # 3) 시나리오3: 206 화재 (F2_ROOM_206): dyn_s3_206_fire
#    (...)
#      12 # 11) 시나리오11: 혼잡도 급증 – 계단1 throughput 급락 → 리라우트 유도: dyn_s11_congestion_spike_stair1
#      13 # 12) 시나리오12: 혼잡도 급증 – EXIT_B throughput 급락 → 리라우트 유도: dyn_s12_congestion_spike_exitB
#      15 res = run_demo_full("dyn_s12_congestion_spike_exitB", 1200)
#
# File ~/overwatch/evacuation_simulator/runners/run_agent_path_demo.py:8
#       1 # run_agent_path_demo.py
#       2 # - 시각화 제거
#       3 # - 선택 agent의 경로/리라우트 타임라인 포함
#       4 # - 전역 통계(Exit별, 완료시간, 리라우트 통계)
#       5 # - reroute_attempts (시도) / reroute_history (실제 변경)
#       6 # - 출구 통계: (1) assigned_exit 기준, (2) 실제 사용된 exit 기준 둘 다 출력
# ----> 8 from astar_logic import load_building
#       9 from scenario_fire_pack import (
#      10     DEFAULT_ASTAR_CFG,
#      11     DEFAULT_REROUTE_POLICY,
#      12     build_agents_with_floor_split,
#      13 )
#      14 from simulation_engine import build_node_dynamics, simulate, compute_stats
#
# ModuleNotFoundError: No module named 'astar_logic'
